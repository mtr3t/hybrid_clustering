# %%
import time
import numpy as np
import plotter as pl
import load_problem as ld
from sklearn.cluster import KMeans
from sklearn.metrics.cluster import normalized_mutual_info_score

# %%
def k_means(problem, ground_truth, printer=False, plotter=False, save_figure=False, axis_hold=False):
    """perform kmeans clustering
    keyword arguments:
        problem: to cluster
        ground_truth: known ground truth of the problem
        printer: print out statments for debugging default=False
        plotter: plot the problem default=False
        save_figure: save figure to figures folder
    returns:
        prints problem location
        prints normalized mutual information score
    """
    
    start = time.time()
    
    # load the problem
    # returns:
        # Y: data points
        # gt: ground truth
        # k: number of clusters for k_means
    Y, gt, k = ld.load_problem(problem, ground_truth, printer, plotter, save_figure, axis_hold)
        
    # perform kmeans
    kmeans = KMeans(n_clusters=k, max_iter=1000, n_init=20).fit(Y)
          
    # calculate the normalized mutual information score
    nmi = normalized_mutual_info_score(gt, kmeans.labels_)
    print(problem, '\nnormalized mutual information score:', nmi)
    
    end = time.time()
    print("time of execution :", (end-start) / 60, "min")
    
    if plotter:
        if Y.shape[1] == 2:           
            prob_type = 'k-means'
            prob_title = str(problem)
            pl.plotter(Y, kmeans.labels_, nmi, prob_type, prob_title, printer, save_figure, axis_hold)

# %%
printer = True
plotter = True
save_figure = True
axis_hold = False
k_means('../05_toy_problems/01_simple_two_and_two.tp',
        '../05_toy_problems/01_simple_two_and_two_ground_truth.tp',
        printer, plotter, save_figure, axis_hold)
# Out:
# problem:
# [[1. 1.]
#  [1. 2.]
#  [9. 8.]
#  [9. 9.]]
#
# problem size: 4 x 2
#
# len ground truth: 4
#
# ground truth:
# [[0]
#  [0]
#  [1]
#  [1]]
#
# number of clusters n: 2
# ../05_toy_problems/01_simple_two_and_two.tp
# normalized mutual information score: 1.0
# time of execution : 0.0026217182477315266 min
#
# labels to be checked:
# [1 1 0 0]
#
# labels returned:
# [0 0 1 1]
#
# k-means labels are:
# [[0]
#  [0]
#  [1]
#  [1]]

# %%
printer = True
plotter = True
save_figure = True
axis_hold = False
k_means('../05_toy_problems/02_simple_four_and_four.tp',
        '../05_toy_problems/02_simple_four_and_four_ground_truth.tp',
        printer, plotter, save_figure, axis_hold)
# Out:
# problem:
# [[1. 1.]
#  [1. 2.]
#  [2. 1.]
#  [2. 2.]
#  [8. 8.]
#  [8. 9.]
#  [9. 8.]
#  [9. 9.]]
#
# problem size: 8 x 2
#
# len ground truth: 8
#
# ground truth:
# [[0]
#  [0]
#  [0]
#  [0]
#  [1]
#  [1]
#  [1]
#  [1]]
#
# number of clusters n: 2
# ../05_toy_problems/02_simple_four_and_four.tp
# normalized mutual information score: 1.0
# time of execution : 0.002188607056935628 min
#
# labels to be checked:
# [1 1 1 1 0 0 0 0]
#
# labels returned:
# [0 0 0 0 1 1 1 1]
#
# k-means labels are:
# [[0]
#  [0]
#  [0]
#  [0]
#  [1]
#  [1]
#  [1]
#  [1]]

# %%
printer = False
plotter = True
save_figure = True
axis_hold = True
k_means('../05_toy_problems/04_two_horizontal_lines_0_to_1.tp',
        '../05_toy_problems/03_ground_truth.tp', printer, plotter, save_figure, axis_hold)
# Out:
# ../05_toy_problems/04_two_horizontal_lines_0_to_1.tp
# normalized mutual information score: 0.0
# time of execution : 0.0024616201718648274 min

# %%
printer = False
plotter = True
save_figure = True
axis_hold = True
k_means('../05_toy_problems/05_two_horizontal_lines_0_to_4.tp',
        '../05_toy_problems/03_ground_truth.tp', printer, plotter, save_figure, axis_hold)
# Out:
# ../05_toy_problems/05_two_horizontal_lines_0_to_4.tp
# normalized mutual information score: 0.0
# time of execution : 0.002173785368601481 min

# %%
printer = False
plotter = True
save_figure = True
axis_hold = True
k_means('../05_toy_problems/06_two_horizontal_lines_0_to_5.tp',
        '../05_toy_problems/03_ground_truth.tp', printer, plotter, save_figure, axis_hold)
# Out:
# ../05_toy_problems/06_two_horizontal_lines_0_to_5.tp
# normalized mutual information score: 1.0
# time of execution : 0.0021582841873168945 min

# %%
printer = False
plotter = True
save_figure = True
axis_hold = False
k_means('../05_toy_problems/07_two_interlocking_circles.tp',
        '../05_toy_problems/03_ground_truth.tp', printer, plotter, save_figure, axis_hold)
# Out:
# ../05_toy_problems/07_two_interlocking_circles.tp
# normalized mutual information score: 0.08507362722027031
# time of execution : 0.0024445652961730957 min

# %%
printer = False
plotter = True
save_figure = True
axis_hold = False
k_means('../05_toy_problems/08_two_interlocking_curves.tp',
        '../05_toy_problems/03_ground_truth.tp', printer, plotter, save_figure, axis_hold)
# Out:
# ../05_toy_problems/08_two_interlocking_curves.tp
# normalized mutual information score: 0.0
# time of execution : 0.0023520509401957195 min

# %%
printer = False
plotter = True
save_figure = True
axis_hold = False
k_means('../05_toy_problems/09_two_subset_circles.tp',
        '../05_toy_problems/03_ground_truth.tp', printer, plotter, save_figure, axis_hold)
# Out:
# ../05_toy_problems/09_two_subset_circles.tp
# normalized mutual information score: 0.0
# time of execution : 0.002275482813517253 min

# %%
printer = False
plotter = True
save_figure = True
axis_hold = False
k_means('../05_toy_problems/10_x.tp',
        '../05_toy_problems/03_ground_truth.tp', printer, plotter, save_figure, axis_hold)
# Out:
# ../05_toy_problems/10_x.tp
# normalized mutual information score: 7.214577140847848e-05
# time of execution : 0.0021138866742451985 min

# %%
# binary aplha digits

# %%
k_means('../06_datasets/01_binary_alpha_digits/02_binary_alpha_digits_0_and_1_78.ds',
        '../06_datasets/01_binary_alpha_digits/02_binary_alpha_digits_0_and_1_78_ground_truth.ds')
# Out:
# ../06_datasets/01_binary_alpha_digits/02_binary_alpha_digits_0_and_1_78.ds
# normalized mutual information score: 1.0
# time of execution : 0.000987247625986735 min

# %%
k_means('../06_datasets/01_binary_alpha_digits/03_binary_alpha_digits_0_and_8_78.ds',
        '../06_datasets/01_binary_alpha_digits/03_binary_alpha_digits_0_and_8_78_ground_truth.ds')
# Out:
# ../06_datasets/01_binary_alpha_digits/03_binary_alpha_digits_0_and_8_78.ds
# normalized mutual information score: 0.9137239091334672
# time of execution : 0.0009003003438313802 min

# %%
k_means('../06_datasets/01_binary_alpha_digits/05_binary_alpha_digits_180.ds',
        '../06_datasets/01_binary_alpha_digits/05_binary_alpha_digits_180_ground_truth.ds')
# Out:
# ../06_datasets/01_binary_alpha_digits/05_binary_alpha_digits_180.ds
# normalized mutual information score: 0.7184729791044678
# time of execution : 0.0027176539103190103 min

# %%
k_means('../06_datasets/01_binary_alpha_digits/04_binary_alpha_digits_468.ds',
        '../06_datasets/01_binary_alpha_digits/04_binary_alpha_digits_468_ground_truth.ds')
# Out:
# ../06_datasets/01_binary_alpha_digits/04_binary_alpha_digits_468.ds
# normalized mutual information score: 0.6469041305594739
# time of execution : 0.004083883762359619 min

# %%
k_means('../06_datasets/01_binary_alpha_digits/01_binary_alpha_digits_1404.ds',
        '../06_datasets/01_binary_alpha_digits/01_binary_alpha_digits_ground_truth_1404.ds')
# Out:
# ../06_datasets/01_binary_alpha_digits/01_binary_alpha_digits_1404.ds
# normalized mutual information score: 0.576521297558989
# time of execution : 0.00745085080464681 min

# %%
# mnist

# %%
k_means('../06_datasets/02_mnist/05_mnist_0_and_1_78.ds',
        '../06_datasets/02_mnist/05_mnist_0_and_1_78_ground_truth.ds')
# Out:
# ../06_datasets/02_mnist/05_mnist_0_and_1_78.ds
# normalized mutual information score: 0.8530024471485607
# time of execution : 0.0011128505071004231 min

# %%
k_means('../06_datasets/02_mnist/06_mnist_0_and_8_78.ds',
        '../06_datasets/02_mnist/06_mnist_0_and_8_78_ground_truth.ds')
# Out:
# ../06_datasets/02_mnist/06_mnist_0_and_8_78.ds
# normalized mutual information score: 0.7677801694949068
# time of execution : 0.0011044979095458985 min

# %%
k_means('../06_datasets/02_mnist/08_mnist_180.ds',
        '../06_datasets/02_mnist/08_mnist_180_ground_truth.ds')
# Out:
# ../06_datasets/02_mnist/08_mnist_180.ds
# normalized mutual information score: 0.5791827936357552
# time of execution : 0.0021685163180033364 min

# %%
k_means('../06_datasets/02_mnist/07_mnist_470.ds',
        '../06_datasets/02_mnist/07_mnist_470_ground_truth.ds')
# Out:
# ../06_datasets/02_mnist/07_mnist_470.ds
# normalized mutual information score: 0.5448103180834517
# time of execution : 0.002983733018239339 min

# %%
k_means('../06_datasets/02_mnist/04_mnist_1400.ds',
        '../06_datasets/02_mnist/04_mnist_1400_ground_truth.ds')
# Out:
# ../06_datasets/02_mnist/04_mnist_1400.ds
# normalized mutual information score: 0.4675882472274829
# time of execution : 0.008024080594380697 min

# %%
# usps

# %%
k_means('../06_datasets/03_usps_handwritten_digits/04_usps_180.ds',
        '../06_datasets/03_usps_handwritten_digits/04_usps_180_ground_truth.ds')
# Out:
# ../06_datasets/03_usps_handwritten_digits/04_usps_180.ds
# normalized mutual information score: 0.5981417286399363
# time of execution : 0.00138701597849528 min

# %%
k_means('../06_datasets/03_usps_handwritten_digits/04_usps_180.ds',
        '../06_datasets/03_usps_handwritten_digits/04_usps_180_ground_truth.ds')
# Out:
# ../06_datasets/03_usps_handwritten_digits/04_usps_180.ds
# normalized mutual information score: 0.6123391022517747
# time of execution : 0.0013875325520833334 min

# %%
k_means('../06_datasets/03_usps_handwritten_digits/03_usps_468.ds',
        '../06_datasets/03_usps_handwritten_digits/03_usps_468_ground_truth.ds')
# Out:
# ../06_datasets/03_usps_handwritten_digits/03_usps_468.ds
# normalized mutual information score: 0.6305902958277083
# time of execution : 0.0019352833429972331 min

# %%
k_means('../06_datasets/03_usps_handwritten_digits/02_usps_1404.ds',
        '../06_datasets/03_usps_handwritten_digits/02_usps_1404_ground_truth.ds')
# Out:
# ../06_datasets/03_usps_handwritten_digits/02_usps_1404.ds
# normalized mutual information score: 0.6523472578964885
# time of execution : 0.003681949774424235 min
