# %%
import numpy as np
import plotter as pl
import load_problem as ld
from sklearn.cluster import KMeans
from sklearn.metrics.cluster import normalized_mutual_info_score

# %%
def k_means(problem, ground_truth, printer=False, plotter=False, save_figure=False):
    """perform kmeans clustering
    keyword arguments:
        problem: to cluster
        ground_truth: known ground truth of the problem
        printer: print out statments for debugging default=False
        plotter: plot the problem default=False
        save_figure: save figure to figures folder
    returns:
        prints problem location
        prints normalized mutual information score
    """
    # load the problem
    # returns:
        # Y: data points
        # gt: ground truth
        # k: number of clusters for k_means
    Y, gt, k = ld.load_problem(problem, ground_truth, printer, plotter, save_figure)
        
    # perform kmeans
    kmeans = KMeans(n_clusters=k, max_iter=1000, n_init=20).fit(Y)
          
    # calculate the normalized mutual information score
    nmi = normalized_mutual_info_score(gt, kmeans.labels_)
    print(problem, '\nnormalized mutual information score:', nmi)
    
    if plotter:
        if Y.shape[1] == 2:           
            prob_type = 'k-means'
            prob_title = str(problem)
            pl.plotter(Y, kmeans.labels_, nmi, prob_type, prob_title, printer, save_figure)

# %%
printer = True
plotter = True
save_figure = True
k_means('toy_problems/01_simple_two_and_two.tp',
        'toy_problems/01_simple_two_and_two_ground_truth.tp',
        printer, plotter, save_figure)
# Out:
# problem:
# [[1. 1.]
#  [1. 2.]
#  [9. 8.]
#  [9. 9.]]
#
# problem size: 4 x 2
#
# len ground truth: 4
#
# ground truth:
# [[0]
#  [0]
#  [1]
#  [1]]
#
# number of clusters n: 2
# toy_problems/01_simple_two_and_two.tp
# normalized mutual information score: 1.0
#
# labels to be checked:
# [0 0 1 1]
#
# labels returned:
# [0 0 1 1]
#
# k-means labels are:
# [[0]
#  [0]
#  [1]
#  [1]]

# %%
printer = True
plotter = True
save_figure = True
k_means('toy_problems/02_simple_four_and_four.tp',
        'toy_problems/02_simple_four_and_four_ground_truth.tp',
        printer, plotter, save_figure)
# Out:
# problem:
# [[1. 1.]
#  [1. 2.]
#  [2. 1.]
#  [2. 2.]
#  [8. 8.]
#  [8. 9.]
#  [9. 8.]
#  [9. 9.]]
#
# problem size: 8 x 2
#
# len ground truth: 8
#
# ground truth:
# [[0]
#  [0]
#  [0]
#  [0]
#  [1]
#  [1]
#  [1]
#  [1]]
#
# number of clusters n: 2
# toy_problems/02_simple_four_and_four.tp
# normalized mutual information score: 1.0
#
# labels to be checked:
# [0 0 0 0 1 1 1 1]
#
# labels returned:
# [0 0 0 0 1 1 1 1]
#
# k-means labels are:
# [[0]
#  [0]
#  [0]
#  [0]
#  [1]
#  [1]
#  [1]
#  [1]]

# %%
printer = False
plotter = True
save_figure = True
k_means('toy_problems/04_two_horizontal_lines_0_to_1.tp',
        'toy_problems/03_ground_truth.tp', printer, plotter, save_figure)
# Out:
# toy_problems/04_two_horizontal_lines_0_to_1.tp
# normalized mutual information score: 0.0

# %%
printer = False
plotter = True
save_figure = True
k_means('toy_problems/05_two_horizontal_lines_0_to_4.tp',
        'toy_problems/03_ground_truth.tp', printer, plotter, save_figure)
# Out:
# toy_problems/05_two_horizontal_lines_0_to_4.tp
# normalized mutual information score: 0.0

# %%
printer = False
plotter = True
save_figure = True
k_means('toy_problems/06_two_horizontal_lines_0_to_5.tp',
        'toy_problems/03_ground_truth.tp', printer, plotter, save_figure)
# Out:
# toy_problems/06_two_horizontal_lines_0_to_5.tp
# normalized mutual information score: 1.0

# %%
printer = False
plotter = True
save_figure = True
k_means('toy_problems/07_two_interlocking_circles.tp',
        'toy_problems/03_ground_truth.tp', printer, plotter, save_figure)
# Out:
# toy_problems/07_two_interlocking_circles.tp
# normalized mutual information score: 0.08507362722027031

# %%
printer = False
plotter = True
save_figure = True
k_means('toy_problems/08_two_interlocking_curves.tp',
        'toy_problems/03_ground_truth.tp', printer, plotter, save_figure)
# Out:
# toy_problems/08_two_interlocking_curves.tp
# normalized mutual information score: 0.0

# %%
printer = False
plotter = True
save_figure = True
k_means('toy_problems/09_two_subset_circles.tp',
        'toy_problems/03_ground_truth.tp', printer, plotter, save_figure)
# Out:
# toy_problems/09_two_subset_circles.tp
# normalized mutual information score: 0.0

# %%
printer = False
plotter = True
save_figure = True
k_means('toy_problems/10_x.tp',
        'toy_problems/03_ground_truth.tp', printer, plotter, save_figure)
# Out:
# toy_problems/10_x.tp
# normalized mutual information score: 7.214577140847848e-05

# %%
k_means('datasets/binary_alpha_digits/02_binary_alpha_digits_0_and_1.ds',
        'datasets/binary_alpha_digits/02_binary_alpha_digits_0_and_1_ground_truth.ds')
# Out:
# datasets/binary_alpha_digits/02_binary_alpha_digits_0_and_1.ds
# normalized mutual information score: 1.0

# %%
k_means('datasets/binary_alpha_digits/03_binary_alpha_digits_0_and_8.ds',
        'datasets/binary_alpha_digits/03_binary_alpha_digits_0_and_8_ground_truth.ds')
# Out:
# datasets/binary_alpha_digits/03_binary_alpha_digits_0_and_8.ds
# normalized mutual information score: 0.9137239091334672

# %%
k_means('datasets/binary_alpha_digits/01_binary_alpha_digits.ds',
        'datasets/binary_alpha_digits/01_binary_alpha_digits_ground_truth.ds')
# Out:
# datasets/binary_alpha_digits/01_binary_alpha_digits.ds
# normalized mutual information score: 0.580960240299452
